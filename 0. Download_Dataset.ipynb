# %% [markdown]
# # ERA5 Climate Data Acquisition
#
# This notebook automates the acquisition of ERA5 reanalysis data from the Copernicus Climate Data Store (CDS). It downloads surface meteorological variables and ocean wave parameters for specified spatial grids and temporal ranges, creating comprehensive datasets for machine learning applications.
#
# **Data Source**: ERA5 hourly data on single levels
# **API Documentation**: [CDS ERA5 Timeseries](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=download)
#
# ## 1. Download Function
#
# Define the function to download, extract, and merge ERA5 surface and wave data into unified NetCDF files.

# %%
import cdsapi
import zipfile
import os
import xarray as xr

def download_era5_combined(latitude, longitude, start_date, end_date, client, out_dir="dataset_test"):
    """
    Download ERA5 single-level timeseries data for both surface and wave variables.
    
    This function retrieves meteorological and oceanographic data from the Copernicus
    Climate Data Store, merges them into a single NetCDF file, and performs cleanup.
    
    Args:
        latitude (float): Latitude coordinate in decimal degrees
        longitude (float): Longitude coordinate in decimal degrees (negative for West)
        start_date (str): Start date in format "YYYY-MM-DD"
        end_date (str): End date in format "YYYY-MM-DD"
        client (cdsapi.Client): Authenticated CDS API client
        out_dir (str): Output directory for downloaded files
    
    Returns:
        str: Path to the merged NetCDF file
    
    Reference:
        https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries
    """
    # Setup output directory and file naming
    os.makedirs(out_dir, exist_ok=True)
    dataset = "reanalysis-era5-single-levels-timeseries"
    
    coord_tag = f"{latitude:.2f}N_{abs(longitude):.2f}{'W' if longitude < 0 else 'E'}"
    date_tag = f"{start_date}_to_{end_date}"
    
    def download_and_extract(variables, label):
        """
        Helper function to download and extract a specific variable set.
        
        Args:
            variables (list): List of ERA5 variable names
            label (str): Label for the variable set (e.g., 'surface', 'wave')
        
        Returns:
            str: Path to the extracted NetCDF file
        """
        tmp_zip = f"{label}_temp.zip"
        
        request = {
            "variable": variables,
            "location": {"longitude": longitude, "latitude": latitude},
            "date": [f"{start_date}/{end_date}"],
            "data_format": "netcdf",
        }
        
        client.retrieve(dataset, request).download(tmp_zip)
        
        # Extract NetCDF file from ZIP archive
        with zipfile.ZipFile(tmp_zip, "r") as z:
            nc_files = [f for f in z.namelist() if f.endswith(".nc")]
            if not nc_files:
                raise FileNotFoundError(f"No .nc file found in {label} ZIP archive.")
            extracted = z.extract(nc_files[0], path=out_dir)
            
            # Rename with descriptive filename
            new_name = f"ERA5_{label}_{coord_tag}_{date_tag}.nc"
            new_path = os.path.join(out_dir, new_name)
            os.rename(extracted, new_path)
        
        os.remove(tmp_zip)
        print(f"{label.capitalize()} variables downloaded: {new_path}")
        return new_path
    
    # Define variable sets
    surface_vars = [
        "2m_dewpoint_temperature",
        "mean_sea_level_pressure",
        "skin_temperature",
        "surface_pressure",
        "surface_solar_radiation_downwards",
        "sea_surface_temperature",
        "surface_thermal_radiation_downwards",
        "2m_temperature",
        "total_precipitation",
        "10m_u_component_of_wind",
        "10m_v_component_of_wind",
    ]
    
    wave_vars = [
        "mean_wave_direction",
        "mean_wave_period",
        "significant_height_of_combined_wind_waves_and_swell",
    ]
    
    # Download both variable sets
    surf_path = download_and_extract(surface_vars, "surface")
    wave_path = download_and_extract(wave_vars, "wave")
    
    # Merge datasets and cleanup temporary files
    ds_surf = xr.open_dataset(surf_path)
    ds_wave = xr.open_dataset(wave_path)
    
    merged = xr.merge([ds_surf, ds_wave], compat="override", join="outer")
    merged_path = os.path.join(out_dir, f"ERA5_{coord_tag}_{date_tag}.nc")
    merged.to_netcdf(merged_path)
    
    ds_surf.close()
    ds_wave.close()
    os.remove(surf_path)
    os.remove(wave_path)
    
    print(f"Merged dataset saved: {merged_path}")
    return merged_path

# %% [markdown]
# ## 2. Spatial Grid Configuration and Batch Download
#
# Configure the spatial domain and temporal range for data acquisition. The notebook supports multiple predefined grid patterns to create training and testing datasets with diverse geographic coverage.

# %%
import numpy as np
import winsound

# Initialize CDS API client
client = cdsapi.Client()

# Define spatial grid patterns
# Training grids: Multiple regions around the Azores archipelago
train_latitudes_list = [
    np.arange(39.50, 40.51, 0.25),  # Grid 1: Northern region
    np.arange(39.75, 40.26, 0.25),  # Grid 2: Central-north region
    np.arange(37.75, 38.51, 0.25),  # Grid 3: Central region
    np.arange(35.25, 36.51, 0.25)   # Grid 4: Southern region
]

train_longitudes_list = [
    np.arange(-32.50, -31.74, 0.25),  # Grid 1: Western sector
    np.arange(-27.00, -25.49, 0.25),  # Grid 2: Eastern sector
    np.arange(-31.50, -29.99, 0.25),  # Grid 3: Central sector
    np.arange(-25.25, -23.99, 0.25)   # Grid 4: Far-eastern sector
]

# Testing grid: Independent region for model evaluation
test_latitudes_list = [np.arange(36.0, 37.01, 0.25)]
test_longitudes_list = [np.arange(-28.5, -27.49, 0.25)]

# Select grid configuration
# Set to 0-3 for training grids, or use test grids
USE_TRAIN_GRID = True
n_group = 0  # Select which grid pattern to download

if USE_TRAIN_GRID:
    latitudes = train_latitudes_list[n_group]
    longitudes = train_longitudes_list[n_group]
    print(f"Downloading TRAINING grid {n_group + 1}")
else:
    latitudes = test_latitudes_list[0]
    longitudes = test_longitudes_list[0]
    print("Downloading TESTING grid")

print(f"Latitudes:  {latitudes}")
print(f"Longitudes: {longitudes}")
print(f"Total locations: {len(latitudes) * len(longitudes)}\n")

# Batch download for all grid points
download_count = 0
failed_count = 0

for lat in latitudes:
    for lon in longitudes:
        try:
            print(f"\nDownloading [{download_count + 1}/{len(latitudes) * len(longitudes)}]: "
                  f"{lat:.2f}N, {abs(lon):.2f}W")
            download_era5_combined(
                latitude=lat,
                longitude=lon,
                start_date="2025-01-01",
                end_date="2025-10-03",
                client=client,
                out_dir="dataset_final"
            )
            download_count += 1
        except Exception as e:
            print(f"✗ Failed for {lat:.2f}N, {abs(lon):.2f}W: {e}")
            failed_count += 1

# Summary
print(f"\n{'='*60}")
print(f"Download Complete!")
print(f"Successful: {download_count}")
print(f"Failed: {failed_count}")
print(f"{'='*60}")

# Audio notification (Windows only)
try:
    duration = 1000  # milliseconds
    freq = 440  # Hz
    winsound.Beep(freq, duration)
except:
    pass  # Skip if not on Windows or sound not available
